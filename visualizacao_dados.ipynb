# %%
import pandas as pd

# %%
df = pd.read_csv('./dados/RECLAMEAQUI_HAPVIDA.csv')

# %%
df.columns
# Out:
# Index(['ID', 'TEMA', 'LOCAL', 'TEMPO', 'CATEGORIA', 'STATUS', 'DESCRICAO',
#        'URL', 'ANO', 'MES', 'DIA', 'DIA_DO_ANO', 'SEMANA_DO_ANO',
#        'DIA_DA_SEMANA', 'TRIMETRES', 'CASOS'],
#       dtype='object')

# %%
df['TEMPO'] = pd.to_datetime(df['TEMPO'])
df['UF'] = df['LOCAL'].apply(lambda x: x.split('-')[-1] if len(x.split('-')[-1]) != 2 else 'ND')
df
# Out:
#              ID                                             TEMA  \
# 0     149490335                            TEMPO DE ATENDIMENTO
# 1     149499817                       Hapvida não tem nutrólogo
# 2     149498293             Descaso de tratamento de Hemodiálise
# 3     149495455  DESORGANIZAÇÃO E FALTA DE RESOLUÇÃO DE PROBLEMA
# 4     149495285                       Liberação de Procedimento
# ...         ...                                              ...
# 1011  150005391                                 Mal atendimento
# 1012  150004057                        Agenda médica nunca abre
# 1013  150000291                             Péssimo atendimento
# 1014  150019173                      Imagem dos exames realizado
# 1015  150001141                            Demora no atendimento
#
#                 LOCAL      TEMPO  \
# 0         Recife - PE 2022-01-09
# 1       Salvador - BA 2022-01-09
# 2         Olinda - PE 2022-01-09
# 3        Goiânia - GO 2022-01-09
# ...

# %%
df.groupby(['ANO', 'MES'], as_index=False)['ID'].count()
# Out:
#      ANO  MES   ID
# 0   2022    1   66
# 1   2022    2   49
# 2   2022    3   18
# 3   2022    4   18
# 4   2022    5   65
# 5   2022    6   64
# 6   2022    7   14
# 7   2022    8  479
# 8   2022    9  135
# 9   2022   10   24
# 10  2022   11   13
# 11  2022   12   71

# %%
df['TEMPO'].values
# Out:
# array(['2017-01-08', '2017-01-09', '2017-01-10', '2017-01-11',
#        '2017-01-12', '2017-02-05', '2017-02-11', '2017-02-17',
#        '2017-02-21', '2017-02-24', '2017-03-08', '2017-03-08',
#        '2017-03-09', '2017-03-09', '2017-03-10', '2017-03-11',
#        '2017-03-12', '2017-03-13', '2017-03-13', '2017-03-15',
#        '2017-03-22', '2017-03-24', '2017-03-25', '2017-03-30',
#        '2017-03-30', '2017-04-03', '2017-04-04', '2017-04-05',
#        '2017-04-06', '2017-04-07', '2017-04-10', '2017-04-11',
#        '2017-04-18', '2017-04-18', '2017-04-19', '2017-04-23',
#        '2017-04-24', '2017-04-25', '2017-04-25', '2017-04-26',
#        '2017-04-29', '2017-04-30', '2017-04-30', '2017-05-05',
#        '2017-05-07', '2017-05-08', '2017-05-15', '2017-05-16',
#        '2017-05-16', '2017-05-17', '2017-05-17', '2017-05-19',
#        '2017-05-22', '2017-05-22', '2017-05-24', '2017-05-28',
#        '2017-05-28', '2017-06-04', '2017-06-07', '2017-06-10',
# ...
